# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %matplotlib inline

device = "cuda" if torch.cuda.is_available() else "cpu"
print("using devie: %s" % device)
# Out:
# using devie: cuda

# %%
from segdataset import SegDataset

DS_ROOT = "E:\\datasets\\prepped"
train_ds = SegDataset(DS_ROOT, "train")
test_ds = SegDataset(DS_ROOT, "test")

print(f"train ds: {len(train_ds)}, test ds: {len(test_ds)}")
# Out:
# train ds: 367, test ds: 101

# %%
def imshow(ds, row, col, figsize=(6, 6)):
    fig, axes = plt.subplots(row, col*2, figsize=figsize)
    axes = list(axes.flat)
    for i in range(row * col):
        img, mask = ds[i]
        axes[i*2].imshow(img.permute(1,2,0))
        axes[i*2 + 1].imshow(mask)
    fig.tight_layout()
    fig.show()

imshow(train_ds, 2, 1, figsize=(10, 10))
# Out:
# C:\Users\liang\AppData\Local\Temp\ipykernel_12620\1098849131.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# trainning preparation
from unet import Unet
from torchsummary import summary

train_dl = DataLoader(train_ds, batch_size=4, shuffle=True)
test_dl = DataLoader(test_ds, batch_size=1, shuffle=False)

model = Unet(pretrained=True)
#model = torch.load("unet_16.pt")
model = model.to(device)
ce = nn.CrossEntropyLoss()
def UnetLoss(preds, targets):
    ce_loss = ce(preds, targets)
    acc = (torch.max(preds, dim=1)[1] == targets).float().mean()
    return ce_loss, acc

#summary(model, (3, 224, 224), device=device)

print(model)

optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, min_lr=1e-5, verbose=True)
        
def train_batch(model, xs, ys, lossfn, optimizer):
    model.train()
    preds = model(xs)
    loss, acc = lossfn(preds, ys)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return loss.item(), acc.item()

@torch.no_grad()
def test_batch(model, xs, ys, lossfn):
    model.eval()
    preds = model(xs)
    loss, acc = lossfn(preds, ys)
    return loss.item(), acc.item()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to C:\Users\liang/.cache\torch\hub\checkpoints\vgg16_bn-6c64b313.pth
# 100%|██████████| 528M/528M [00:26<00:00, 20.7MB/s]
# Unet(
#   (encoder): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (block2): Sequential(
#     (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#     (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#   )
#   (block3): Sequential(
#     (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#   )
#   (block4): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#   )
#   (block5): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (bottleneck): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_bottleneck): Sequential(
#     (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (up_conv6): Sequential(
#     (0): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (up_conv7): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv7): Sequential(
#     (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (up_conv8): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv8): Sequential(
#     (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (up_conv9): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv9): Sequential(
#     (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (up_conv10): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): ReLU(inplace=True)
#   )
#   (conv10): Sequential(
#     (0): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv11): Conv2d(32, 12, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
# training
import time 
import numpy as np

for epoch in range(17, 100):
    start = time.time()

    losses = []
    acces = []
    for xs, ys in train_dl:
        xs = xs.to(device)
        ys = ys.to(device)
        loss, acc = train_batch(model, xs, ys, UnetLoss, optimizer)
        losses.append(loss)
        acces.append(acc)
    epoch_train_loss = np.mean(losses)
    epoch_train_acc = np.mean(acces)

    losses = []
    acces = []
    for xs, ys in test_dl:
        xs = xs.to(device)
        ys = ys.to(device)
        loss, acc = test_batch(model, xs, ys, UnetLoss)
        losses.append(loss)
        acces.append(acc)
    epoch_test_loss = np.mean(losses)
    epoch_test_acc = np.mean(acces)
    lr_scheduler.step(epoch_test_loss)

    consume = time.time() - start
    print(f"epoch {epoch}, consume {consume:.0f}s: \
        train loss={epoch_train_loss:.2f}, test loss = {epoch_test_loss:.2f}, \
        train acc = {epoch_train_acc:.2f}, test acc = {epoch_test_acc:.2f}")
    torch.save(model, f"unet_{epoch}.pt")
# Out:
# epoch 17, consume 17s:         train loss=1.16, test loss = 0.83,         train acc = 0.75, test acc = 0.82
# epoch 18, consume 7s:         train loss=0.70, test loss = 0.74,         train acc = 0.82, test acc = 0.82
# epoch 19, consume 7s:         train loss=0.60, test loss = 0.58,         train acc = 0.84, test acc = 0.86
# epoch 20, consume 7s:         train loss=0.51, test loss = 0.53,         train acc = 0.86, test acc = 0.86
# epoch 21, consume 7s:         train loss=0.49, test loss = 0.58,         train acc = 0.87, test acc = 0.84
# epoch 22, consume 7s:         train loss=0.46, test loss = 0.65,         train acc = 0.87, test acc = 0.82
# epoch 23, consume 7s:         train loss=0.42, test loss = 0.49,         train acc = 0.88, test acc = 0.87
# epoch 24, consume 7s:         train loss=0.40, test loss = 0.48,         train acc = 0.89, test acc = 0.85
# epoch 25, consume 7s:         train loss=0.37, test loss = 0.43,         train acc = 0.89, test acc = 0.87
# epoch 26, consume 7s:         train loss=0.37, test loss = 0.43,         train acc = 0.90, test acc = 0.87
# epoch 27, consume 7s:         train loss=0.34, test loss = 0.42,         train acc = 0.90, test acc = 0.87
# epoch 28, consume 7s:         train loss=0.33, test loss = 0.46,         train acc = 0.90, test acc = 0.87
# epoch 29, consume 7s:         train loss=0.31, test loss = 0.37,         train acc = 0.91, test acc = 0.90
# epoch 30, consume 7s:         train loss=0.29, test loss = 0.35,         train acc = 0.92, test acc = 0.90
# epoch 31, consume 7s:         train loss=0.27, test loss = 0.32,         train acc = 0.92, test acc = 0.91
# epoch 32, consume 7s:         train loss=0.26, test loss = 0.39,         train acc = 0.93, test acc = 0.89
# epoch 33, consume 7s:         train loss=0.26, test loss = 0.45,         train acc = 0.93, test acc = 0.88
# epoch 34, consume 7s:         train loss=0.25, test loss = 0.37,         train acc = 0.93, test acc = 0.89
# epoch 35, consume 7s:         train loss=0.24, test loss = 0.32,         train acc = 0.93, test acc = 0.91
# epoch 36, consume 7s:         train loss=0.23, test loss = 0.34,         train acc = 0.93, test acc = 0.91
# Epoch    21: reducing learning rate of group 0 to 5.0000e-04.
# epoch 37, consume 7s:         train loss=0.23, test loss = 0.35,         train acc = 0.93, test acc = 0.90
# epoch 38, consume 7s:         train loss=0.21, test loss = 0.34,         train acc = 0.94, test acc = 0.91
# epoch 39, consume 7s:         train loss=0.20, test loss = 0.35,         train acc = 0.94, test acc = 0.91
# epoch 40, consume 7s:         train loss=0.20, test loss = 0.36,         train acc = 0.94, test acc = 0.91
# epoch 41, consume 7s:         train loss=0.19, test loss = 0.35,         train acc = 0.95, test acc = 0.91
# epoch 42, consume 7s:         train loss=0.19, test loss = 0.39,         train acc = 0.95, test acc = 0.90
# Epoch    27: reducing learning rate of group 0 to 2.5000e-04.
# epoch 43, consume 7s:         train loss=0.18, test loss = 0.36,         train acc = 0.95, test acc = 0.91
# epoch 44, consume 7s:         train loss=0.18, test loss = 0.37,         train acc = 0.95, test acc = 0.91
# epoch 45, consume 7s:         train loss=0.18, test loss = 0.38,         train acc = 0.95, test acc = 0.91
# epoch 46, consume 7s:         train loss=0.17, test loss = 0.38,         train acc = 0.95, test acc = 0.91
# epoch 47, consume 7s:         train loss=0.17, test loss = 0.39,         train acc = 0.95, test acc = 0.91
# epoch 48, consume 7s:         train loss=0.17, test loss = 0.39,         train acc = 0.95, test acc = 0.91
# Epoch    33: reducing learning rate of group 0 to 1.2500e-04.
# epoch 49, consume 7s:         train loss=0.17, test loss = 0.39,         train acc = 0.95, test acc = 0.91
# epoch 50, consume 7s:         train loss=0.16, test loss = 0.39,         train acc = 0.95, test acc = 0.91
# epoch 51, consume 7s:         train loss=0.16, test loss = 0.40,         train acc = 0.95, test acc = 0.91
# epoch 52, consume 7s:         train loss=0.16, test loss = 0.40,         train acc = 0.95, test acc = 0.91
# epoch 53, consume 7s:         train loss=0.16, test loss = 0.40,         train acc = 0.95, test acc = 0.91
# epoch 54, consume 7s:         train loss=0.16, test loss = 0.40,         train acc = 0.95, test acc = 0.91
# Epoch    39: reducing learning rate of group 0 to 6.2500e-05.
# epoch 55, consume 7s:         train loss=0.16, test loss = 0.40,         train acc = 0.95, test acc = 0.91
# epoch 56, consume 7s:         train loss=0.16, test loss = 0.41,         train acc = 0.95, test acc = 0.91
# epoch 57, consume 7s:         train loss=0.16, test loss = 0.41,         train acc = 0.95, test acc = 0.91
# epoch 58, consume 7s:         train loss=0.15, test loss = 0.41,         train acc = 0.96, test acc = 0.91
# epoch 59, consume 7s:         train loss=0.15, test loss = 0.41,         train acc = 0.96, test acc = 0.91
# epoch 60, consume 7s:         train loss=0.15, test loss = 0.41,         train acc = 0.96, test acc = 0.91
# Epoch    45: reducing learning rate of group 0 to 3.1250e-05.
# epoch 61, consume 7s:         train loss=0.15, test loss = 0.42,         train acc = 0.96, test acc = 0.91
# epoch 62, consume 7s:         train loss=0.15, test loss = 0.42,         train acc = 0.96, test acc = 0.91
# epoch 63, consume 7s:         train loss=0.15, test loss = 0.42,         train acc = 0.96, test acc = 0.91
# epoch 64, consume 7s:         train loss=0.15, test loss = 0.42,         train acc = 0.96, test acc = 0.91
# epoch 65, consume 7s:         train loss=0.15, test loss = 0.42,         train acc = 0.96, test acc = 0.91
# epoch 66, consume 7s:         train loss=0.15, test loss = 0.42,         train acc = 0.96, test acc = 0.91
# Epoch    51: reducing learning rate of group 0 to 1.5625e-05.
# epoch 67, consume 7s:         train loss=0.15, test loss = 0.42,         train acc = 0.96, test acc = 0.91
# epoch 68, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 69, consume 7s:         train loss=0.15, test loss = 0.42,         train acc = 0.96, test acc = 0.91
# epoch 70, consume 7s:         train loss=0.15, test loss = 0.42,         train acc = 0.96, test acc = 0.91
# epoch 71, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 72, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# Epoch    57: reducing learning rate of group 0 to 1.0000e-05.
# epoch 73, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 74, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 75, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 76, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 77, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 78, consume 7s:         train loss=0.15, test loss = 0.44,         train acc = 0.96, test acc = 0.91
# epoch 79, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 80, consume 7s:         train loss=0.15, test loss = 0.44,         train acc = 0.96, test acc = 0.90
# epoch 81, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.90
# epoch 82, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 83, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 84, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 85, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 86, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 87, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 88, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 89, consume 7s:         train loss=0.15, test loss = 0.44,         train acc = 0.96, test acc = 0.90
# epoch 90, consume 7s:         train loss=0.15, test loss = 0.44,         train acc = 0.96, test acc = 0.90
# epoch 91, consume 7s:         train loss=0.15, test loss = 0.44,         train acc = 0.96, test acc = 0.91
# epoch 92, consume 7s:         train loss=0.15, test loss = 0.44,         train acc = 0.96, test acc = 0.90
# epoch 93, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 94, consume 7s:         train loss=0.15, test loss = 0.44,         train acc = 0.96, test acc = 0.91
# epoch 95, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 96, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 97, consume 7s:         train loss=0.15, test loss = 0.44,         train acc = 0.96, test acc = 0.91
# epoch 98, consume 7s:         train loss=0.15, test loss = 0.43,         train acc = 0.96, test acc = 0.91
# epoch 99, consume 7s:         train loss=0.15, test loss = 0.44,         train acc = 0.96, test acc = 0.91

# %%
model = torch.load('unet_99.pt')
model.eval()

img, mask = test_ds.choose()
preds = model(img[None].to(device))
preds_mask = torch.max(preds, dim=1)[1][0].cpu()

print(mask.shape)
print(preds_mask.shape)

fig, axes = plt.subplots(1, 3, figsize=(10, 10))

axes[0].imshow(img.permute(1,2,0))
axes[1].imshow(mask)
axes[2].imshow(preds_mask)
fig.tight_layout()
fig.show()
# Out:
# torch.Size([224, 224])
# torch.Size([224, 224])
# C:\Users\liang\AppData\Local\Temp\ipykernel_12620\442989449.py:17: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
